# %% [markdown]
# ## Name: K Lalith Aditya
#
# ## Regd No: 22231
#
# ## Date: 8/03/2023
#
# ## R-Lab: Work on ggplot2
#
# ## Assignment 5

# %%
library(ggplot2)
data(iris)


IrisPlot <- ggplot(iris, aes(Sepal.Length, Petal.Length, colour=Species)) + geom_point(size=2.56)
print(IrisPlot)
# Out:
# plot without title

# %% [markdown]
# ## Labelling the plot

# %%
print(IrisPlot + labs(y="Petal length (cm)", x = "Sepal length (cm)") 
   + ggtitle("Petal and sepal length of iris"))
# Out:
# plot without title

# %% [markdown]
# ### Highlight and Tick marks on the plot

# %%
# add text
IrisPlot + annotate("text",x=6,y=5,label='text')
# Out:
# plot without title

# %%
# add repeat
IrisPlot + annotate("text",x=4:6, y =5:7, label = "text")
# Out:
# plot without title

# %% [markdown]
# ### highlight an area

# %%
IrisPlot + annotate("rect", xmin = 5, xmax = 7,ymin = 4, ymax = 6, alpha = 0.5)
# Out:
# plot without title

# %% [markdown]
# ### segment

# %%
IrisPlot + annotate("segment",x=5, xend = 7, y = 4, yend = 5, colour = "black")
# Out:
# plot without title

# %% [markdown]
# ## Working on USArrests Dataset

# %%
USArrests
# Out:
#                Murder Assault UrbanPop Rape
# Alabama        13.2   236     58       21.2
# Alaska         10.0   263     48       44.5
# Arizona         8.1   294     80       31.0
# Arkansas        8.8   190     50       19.5
# California      9.0   276     91       40.6
# Colorado        7.9   204     78       38.7
# Connecticut     3.3   110     77       11.1
# Delaware        5.9   238     72       15.8
# Florida        15.4   335     80       31.9
# Georgia        17.4   211     60       25.8
# Hawaii          5.3    46     83       20.2
# Idaho           2.6   120     54       14.2
# Illinois       10.4   249     83       24.0
# Indiana         7.2   113     65       21.0
# Iowa            2.2    56     57       11.3
# Kansas          6.0   115     66       18.0
# Kentucky        9.7   109     52       16.3
# Louisiana      15.4   249     66       22.2
# Maine           2.1    83     51        7.8
# Maryland       11.3   300     67       27.8
# ...

# %% [markdown]
# ## Simple plot with required x and y axis

# %%
bp <- ggplot(USArrests, aes(x=Murder,y =Assault)) + geom_point(size=3.5) 
bp
# Out:
# plot without title

# %% [markdown]
# ### Working with legends

# %%
head(iris)
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1 5.1          3.5         1.4          0.2         setosa
# 2 4.9          3.0         1.4          0.2         setosa
# 3 4.7          3.2         1.3          0.2         setosa
# 4 4.6          3.1         1.5          0.2         setosa
# 5 5.0          3.6         1.4          0.2         setosa
# 6 5.4          3.9         1.7          0.4         setosa

# %%
#plot
p<-ggplot(iris, aes(Sepal.Length, Petal.Length, colour=Species)) + geom_point()
p
# Out:
# plot without title

# %% [markdown]
# ### Changing attributes for legends

# %%
#Remove Legend
p + theme(legend.position="none")
# Out:
# plot without title

# %% [markdown]
# ### Changing the legend position
# ## Top Representation

# %%
p + theme(legend.position = "top")
# Out:
# plot without title

# %% [markdown]
# ## Changing style of legends
# ### Changing the legend title and text font styles

# %%
# legend title
p + theme(legend.title = element_text(colour = "blue", size = 10,))
# Out:
# plot without title

# %% [markdown]
# # Scatter Plots

# %%
ggplot(iris, aes(Sepal.Length,Petal.Length)) +  geom_point()
# Out:
# plot without title

# %% [markdown]
# ### Adding attributes
# ### This is giving the shape of the scatter points

# %%
ggplot(iris, aes(Sepal.Length, Petal.Length)) + geom_point(shape=6)
# Out:
# plot without title

# %% [markdown]
# ## color

# %%
ggplot(iris, aes(Sepal.Length,Petal.Length,colour=Species)) + geom_point(shape=2)
# Out:
# plot without title

# %% [markdown]
# ### geom_smooth function aids the pattern of overlapping and creating the pattern of required variables

# %%
ggplot(iris, aes(Sepal.Length, Petal.Length, colour=Species)) +
geom_point(shape=1,size=3) +
 geom_smooth(method=lm)
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %% [markdown]
# # Jitter Plots

# %%
ggplot(iris,aes(Sepal.Length,Petal.Length)) + geom_point(size=1.5) + geom_jitter(aes(colour=Species))
# Out:
# plot without title

# %% [markdown]
# # Bar Graph

# %%
data(mpg)
mpg
# Out:
#     manufacturer model              displ year cyl trans      drv cty hwy fl
# 1   audi         a4                 1.8   1999 4   auto(l5)   f   18  29  p
# 2   audi         a4                 1.8   1999 4   manual(m5) f   21  29  p
# 3   audi         a4                 2.0   2008 4   manual(m6) f   20  31  p
# 4   audi         a4                 2.0   2008 4   auto(av)   f   21  30  p
# 5   audi         a4                 2.8   1999 6   auto(l5)   f   16  26  p
# 6   audi         a4                 2.8   1999 6   manual(m5) f   18  26  p
# 7   audi         a4                 3.1   2008 6   auto(av)   f   18  27  p
# 8   audi         a4 quattro         1.8   1999 4   manual(m5) 4   18  26  p
# 9   audi         a4 quattro         1.8   1999 4   auto(l5)   4   16  25  p
# 10  audi         a4 quattro         2.0   2008 4   manual(m6) 4   20  28  p
# 11  audi         a4 quattro         2.0   2008 4   auto(s6)   4   19  27  p
# ...

# %%
p <- ggplot(mpg,aes(x = factor(class))) + geom_bar(stat = "count")
p
# Out:
# plot without title

# %% [markdown]
# # Histogram

# %%
mpg
# Out:
#     manufacturer model              displ year cyl trans      drv cty hwy fl
# 1   audi         a4                 1.8   1999 4   auto(l5)   f   18  29  p
# 2   audi         a4                 1.8   1999 4   manual(m5) f   21  29  p
# 3   audi         a4                 2.0   2008 4   manual(m6) f   20  31  p
# 4   audi         a4                 2.0   2008 4   auto(av)   f   21  30  p
# 5   audi         a4                 2.8   1999 6   auto(l5)   f   16  26  p
# 6   audi         a4                 2.8   1999 6   manual(m5) f   18  26  p
# 7   audi         a4                 3.1   2008 6   auto(av)   f   18  27  p
# 8   audi         a4 quattro         1.8   1999 4   manual(m5) 4   18  26  p
# 9   audi         a4 quattro         1.8   1999 4   auto(l5)   4   16  25  p
# 10  audi         a4 quattro         2.0   2008 4   manual(m6) 4   20  28  p
# 11  audi         a4 quattro         2.0   2008 4   auto(s6)   4   19  27  p
# ...

# %%
ggplot(data=mpg, aes(x=hwy)) + geom_histogram(col='red',fill='green',alpha=.3,binwidth = 5)
# Out:
# plot without title

# %% [markdown]
# # Pie Chart

# %%
df <- as.data.frame(table(iris$Species))
df
# Out:
#   Var1       Freq
# 1 setosa     50
# 2 versicolor 50
# 3 virginica  50

# %%
pie <- ggplot(df, aes(x="",y =Freq, fill = factor(Var1))) + geom_bar(width = 1, stat = "identity") + theme(axis.line = element_blank(),
plot.title = element_text(hjust=0.5)) +
    labs(fill="Freq",
       x=NULL,
       y=NULL, 
       title="Pie Chart of Variety of iris Species",
       caption="Source: iris")

# %%
pie + coord_polar(theta = "y", start=0)
# Out:
# plot without title

# %% [markdown]
# # Marginal Plots

# %%
library(ggExtra)

# %%
data(USArrests)
head(USArrests)
# Out:
#            Murder Assault UrbanPop Rape
# Alabama    13.2   236     58       21.2
# Alaska     10.0   263     48       44.5
# Arizona     8.1   294     80       31.0
# Arkansas    8.8   190     50       19.5
# California  9.0   276     91       40.6
# Colorado    7.9   204     78       38.7

# %%
# Plot
g <- ggplot(USArrests, aes(Murder,Assault)) + geom_count() + geom_smooth(method='lm',se=F)
g
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %% [markdown]
# # Bubble Chart

# %%
head(mpg)
# Out:
#   manufacturer model displ year cyl trans      drv cty hwy fl class
# 1 audi         a4    1.8   1999 4   auto(l5)   f   18  29  p  compact
# 2 audi         a4    1.8   1999 4   manual(m5) f   21  29  p  compact
# 3 audi         a4    2.0   2008 4   manual(m6) f   20  31  p  compact
# 4 audi         a4    2.0   2008 4   auto(av)   f   21  30  p  compact
# 5 audi         a4    2.8   1999 6   auto(l5)   f   16  26  p  compact
# 6 audi         a4    2.8   1999 6   manual(m5) f   18  26  p  compact

# %%
ggplot(mpg, aes(x=cty, y=displ, size = 10)) +geom_point(alpha=0.7,color='red')
# Out:
# plot without title

# %% [markdown]
# # Themes

# %%
library('ggthemes')

# %%
ggplot(mpg, aes(year, displ, color=factor(manufacturer))) + geom_point() + ggtitle("Look is different from the default") + theme_economist() + scale_colour_economist()
# Out:
# Warning message in check_pal_n(n, max_n):
# "This palette can handle a maximum of 9 values.You have supplied 15."
# Warning message:
# "Removed 97 rows containing missing values (`geom_point()`)."
# plot without title

# %%
theme_set(theme_gray(base_size = 30))
ggplot(mpg, aes(x = year, y = class)) + geom_point(color="red")
# Out:
# plot without title
